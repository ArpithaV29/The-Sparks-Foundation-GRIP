# %% [markdown]
# **By Arpitha Venkatesh Prasad**

# %% [markdown]
# # Task 3 - Exploratory Data Analysis - Retail

# %% [markdown]
# **Including all the libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %% [markdown]
# **To Read the .csv file and to display first and last 5 rows of the dataset.**

# %%
url="/content/drive/MyDrive/SampleSuperstore.csv"
df = pd.read_csv(url)
# To display the top 5 rows
df.head(5)
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
df.tail(5)
# Out:
#            Ship Mode   Segment        Country  ... Quantity Discount   Profit
# 9989    Second Class  Consumer  United States  ...        3      0.2   4.1028
# 9990  Standard Class  Consumer  United States  ...        2      0.0  15.6332
# 9991  Standard Class  Consumer  United States  ...        2      0.2  19.3932
# 9992  Standard Class  Consumer  United States  ...        4      0.0  13.3200
# 9993    Second Class  Consumer  United States  ...        2      0.0  72.9480
#
# [5 rows x 13 columns]

# %% [markdown]
# **Checking the data type and description of the data.**

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# **To check all null columns and get the unique data in the Category column.**

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df["Category"].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %% [markdown]
# **Category Wise Pair Plot**

# %%
sns.pairplot(df,hue='Category')

# %% [markdown]
# **MOST SOLD CATEGORY IS SHOWN BY PLOTTED GRAPH BELOW**

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["Category"])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(12,10))
df['Category'].value_counts().plot.pie(autopct='dark')
plt.show()

# %% [markdown]
# **unique data in Sub-Category column**

# %%
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# **THE MOST SOLD SUB-CATEGORY IS SHOWN BY THE PLOTTED GRAPH BELOW**

# %%
plt.figure(figsize=(12,10))
df['Sub-Category'].value_counts().plot.pie(autopct='dark')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(df["Sub-Category"])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **unique data in segment column.**

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %% [markdown]
# **WHO ORDERS THE MOST SEGMENT IS SHOWN IN THE PLOTTED GRAPH BELOW.**

# %%
plt.figure(figsize=(12,10))
df['Segment'].value_counts().plot.pie(autopct='dark')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["Segment"])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Unique data in Country,State,City and Region column.**

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
df['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
df['City'].value_counts()
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Portage            1
# Conway             1
# Vacaville          1
# Davis              1
# Port Orange        1
# Name: City, Length: 531, dtype: int64

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %% [markdown]
# **Graphical visualization of State,City and Region.**

# %%
plt.figure(figsize=(12,10))
df['State'].value_counts().plot.pie(autopct='dark')
plt.show()
plt.figure(figsize=(12,10))
df['City'].value_counts().plot.pie(autopct='dark')
plt.show()
plt.figure(figsize=(12,10))
df['Region'].value_counts().plot.pie(autopct='dark')
plt.show()

# %% [markdown]
# **WHICH STATE AND CITY ORDERED THE MOST(TOP 5)**

# %%
 df["State"].value_counts().head(5)
plt.figure(figsize=(15,6))
sns.countplot(x=df['State'], order=(df['State'].value_counts().head(5)).index)
plt.show()

# %%
df["City"].value_counts().head(5)
plt.figure(figsize=(15,6))
sns.countplot(x=df['City'], order=(df['City'].value_counts().head(5)).index)
plt.show()

# %%
#data visualization of region.
plt.figure(figsize=(10,5))
sns.countplot(df["Region"])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Widely used shipping mode**

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %% [markdown]
# **Most used Ship Mode is shown in the plotted graph below.**

# %%
plt.figure(figsize=(12,10))
df['Ship Mode'].value_counts().plot.pie(autopct='dark')
plt.show()
plt.figure(figsize=(10,5))
sns.countplot(df["Ship Mode"])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Sales for each sub category with respect to the Category.**

# %%
avg_sl=df.groupby(['Sub-Category','Category'])['Sales'].mean().unstack()
plt.rcParams["figure.figsize"] = (12,6)
avg_sl.plot(kind='bar')
plt.title('Avg Sales for each Category & sub-Category.')
plt.legend(loc='upper right',ncol=4)
plt.show()

# %% [markdown]
# **Profit/Loss & Sales of each parameter in the dataset**

# %%
df.groupby("Category")[[ 'Sales','Profit']].sum().plot.bar(color = ["blue","green"],figsize= (8,5))
plt.ylabel("Profit /loss and Sales")
plt.show()

# %%
pro_los_states=df.groupby('State').agg({'Sales':'sum','Profit':'sum'}).sort_values(by = "Sales", ascending = False)
print(pro_los_states)
pro_los_states.plot.bar(color = ["blue", "green"],figsize= (18,15))
plt.title("Profit/Loss & Sales in every States")
plt.xlabel("States")
plt.ylabel("Profit/Loss & Sales")
plt.show()
# Out:
#                             Sales      Profit
# State
# California            457687.6315  76381.3871
# New York              310876.2710  74038.5486
# Texas                 170188.0458 -25729.3563
# Washington            138641.2700  33402.6517
# Pennsylvania          116511.9140 -15559.9603
# Florida                89473.7080  -3399.3017
# Illinois               80166.1010 -12607.8870
# Ohio                   78258.1360 -16971.3766
# Michigan               76269.6140  24463.1876
# Virginia               70636.7200  18597.9504
# North Carolina         55603.1640  -7490.9122
# Indiana                53555.3600  18382.9363
# Georgia                49095.8400  16250.0433
# Kentucky               36591.7500  11199.6966
# New Jersey             35764.3120   9772.9138
# Arizona                35282.0010  -3427.9246
# Wisconsin              32114.6100   8401.8004
# Colorado               32108.1180  -6527.8579
# Tennessee              30661.8730  -5341.6936
# ...

# %%
pro_los_city=df.groupby('City').agg({'Sales':'sum','Profit':'sum'}).sort_values(by = "Sales", ascending = False).head(50)
print(pro_los_city)
pro_los_city.plot.bar(color = ["blue", "green"],figsize= (18,15))
plt.title("Profit/Loss & Sales in every City")
plt.xlabel("City")
plt.ylabel("Profit/Loss & Sales")
plt.show()
# Out:
#                        Sales      Profit
# City
# New York City    256368.1610  62036.9837
# Los Angeles      175851.3410  30440.7579
# Seattle          119540.7420  29156.0967
# San Francisco    112669.0920  17507.3854
# Philadelphia     109077.0130 -13837.7674
# Houston           64504.7604 -10153.5485
# Chicago           48539.5410  -6654.5688
# San Diego         47521.0290   6377.1960
# Jacksonville      44713.1830  -2323.8350
# Springfield       43054.3420   6200.6974
# Detroit           42446.9440  13181.7908
# Columbus          38706.2430   5897.1013
# Newark            28576.1190   5793.7588
# Columbia          25283.3240   5606.1167
# Lafayette         25036.2000  10018.3876
# Jackson           24963.8580   7581.6828
# San Antonio       21843.5280  -7299.0502
# Burlington        21668.0820  -3622.8772
# Arlington         20214.5320   4169.6969
# Dallas            20131.9322  -2846.5257
# Lakewood          18192.0470   3234.0278
# Richmond          18137.9300   5567.2486
# ...

# %%
pro_los_region=df.groupby('Region').agg({'Sales':'sum','Profit':'sum'}).sort_values(by = "Sales", ascending = False)
print(pro_los_region)
pro_los_region.plot.bar(color = ["blue", "green"],figsize= (10,7))
plt.title("Profit/Loss & Sales for each Region")
plt.xlabel("Region")
plt.ylabel("Profit/Loss & Sales")
# Out:
#                Sales       Profit
# Region
# West     725457.8245  108418.4489
# East     678781.2400   91522.7800
# Central  501239.8908   39706.3625
# South    391721.9050   46749.4303
# Text(0, 0.5, 'Profit/Loss & Sales')

# %%
pro_los_Segment=df.groupby('Segment').agg({'Sales':'sum','Profit':'sum'}).sort_values(by = "Sales", ascending = False)
print(pro_los_Segment)
pro_los_Segment.plot.bar(color = ["blue", "green"],figsize= (10,7))
plt.title("Profit/Loss & Sales for each Segment")
plt.xlabel("Region")
plt.ylabel("Profit/Loss & Sales")
# Out:
#                     Sales       Profit
# Segment
# Consumer     1.161401e+06  134119.2092
# Corporate    7.061464e+05   91979.1340
# Home Office  4.296531e+05   60298.6785
# Text(0, 0.5, 'Profit/Loss & Sales')

# %%
pro_los_subcat=df.groupby('Sub-Category').agg({'Sales':'sum','Profit':'sum'}).sort_values(by = "Sales", ascending = False)
print(pro_los_subcat)
pro_los_subcat.plot.bar(color = ["blue", "green"],figsize= (15,20))
plt.title("Profit/Loss & Sales for each Sub-Category")
plt.xlabel("Sub-Category")
plt.ylabel("Profit/Loss & Sales")
# Out:
#                     Sales      Profit
# Sub-Category
# Phones        330007.0540  44515.7306
# Chairs        328449.1030  26590.1663
# Storage       223843.6080  21278.8264
# Tables        206965.5320 -17725.4811
# Binders       203412.7330  30221.7633
# Machines      189238.6310   3384.7569
# Accessories   167380.3180  41936.6357
# Copiers       149528.0300  55617.8249
# Bookcases     114879.9963  -3472.5560
# Appliances    107532.1610  18138.0054
# Furnishings    91705.1640  13059.1436
# Paper          78479.2060  34053.5693
# Supplies       46673.5380  -1189.0995
# Art            27118.7920   6527.7870
# Envelopes      16476.4020   6964.1767
# Labels         12486.3120   5546.2540
# Fasteners       3024.2800    949.5182
# Text(0, 0.5, 'Profit/Loss & Sales')

# %%
pro_los_ShipMode=df.groupby('Ship Mode').agg({'Sales':'sum','Profit':'sum'}).sort_values(by = "Sales", ascending = False)
print(pro_los_ShipMode)
pro_los_ShipMode.plot.bar(color = ["blue", "green"],figsize= (10,7))
plt.title("Profit/Loss & Sales for each Ship Mode")
plt.xlabel("Ship Mode")
plt.ylabel("Profit/Loss & Sales")
# Out:
#                        Sales       Profit
# Ship Mode
# Standard Class  1.358216e+06  164088.7875
# Second Class    4.591936e+05   57446.6354
# First Class     3.514284e+05   48969.8399
# Same Day        1.283631e+05   15891.7589
# Text(0, 0.5, 'Profit/Loss & Sales')

# %% [markdown]
# **Observations :**
#
#   Maximize the sales in the states of Texas,Ohio,Pennsylvania and Illinois.
#
#   Maximize the sales in the city of  Philadelphia,Houston,San Antonio and Chicago.
#
#  Ship Mode: First Class & Same Day
#
#   Segment:Home & Office
#
#   Region: Central & South
#
#   Category:Furniture
#
#   Sub Category:Tables & Bookcases
#
# **These are the factors which should be followed in order to obtain profit.**

# %% [markdown]
# # Thank You
